# %% [markdown]
# This is your Lab 1 Worksheet. Usually, you will have several problems to solve. Today, however, the main purpose is to make sure that you can download the Jupyter notebooks, complete them, and upload to Gradescope. Note that your class notebooks will not be submitted, but your lab notebooks will. So today, you just need to submit this.

# %% [markdown]
# Enter your name and your lab section here: John Doe, C1

# %% [markdown]
# Problem 1: Create a variable 'myint' and assign your favorite number to it.  Divide 'myint' by 3 and assign it to 'ans'.  Print the values and types of 'myint' and 'ans'.

# %%
#
