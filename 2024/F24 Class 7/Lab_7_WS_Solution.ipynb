# %% [markdown]
# Lab 7 Worksheet
#
# Name:

# %% [markdown]
# Write a script that will prompt the user for positive numbers, and print a running sum of the numbers, until the user enters a zero or a negative number. Then, also print the end result.

# %%
# 1
runsum = 0
posnum = float(input('Enter a positive number: '))
while posnum > 0:
    runsum = runsum + posnum
    print('The sum of the numbers so far is', runsum)
    posnum = float(input('Enter a positive number: '))
print('The end result was', runsum)
# Out:
# Enter a positive number: 5
# The sum of the numbers so far is 5.0
# Enter a positive number: 1.1
# The sum of the numbers so far is 6.1
# Enter a positive number: -4
# The end result was 6.1

# %% [markdown]
# Write a script that will prompt the user for positive numbers until the user enters a negative number. Calculate and print the average of the positive numbers, or an error message if no positive numbers are entered. So, you will need to sum the numbers and keep a count.

# %%
# 2
runsum = 0
mycount = 0
posnum = float(input('Enter a positive number: '))
while posnum >= 0:
    runsum = runsum + posnum
    mycount = mycount + 1
    posnum = float(input('Enter a positive number: '))
if mycount == 0:
    print('No positive numbers were entered.')
else:
    print('The average of the positive numbers is', runsum/mycount)
# Out:
# Enter a positive number: -5
# No positive numbers were entered.

# %% [markdown]
# Write a script that will prompt the user for minimum and maximum integers, and then another integer which is the user's choice in the range from the minimum to the maximum. The script will then generate random integers in the range from the minimum to the maximum, until a match for the user's choice is generated. The script will print how many random integers had to be generated until a match for the user's choice was found. Think about what kind of error-checking should be done!

# %%
# 3

from random import randint

mymin = int(input('Enter a minimum integer: '))

mymax = int(input('Enter a maximum integer: '))
while mymax <= mymin:
    print('The maximum must be greater than the minimum.')
    mymax = int(input('Enter a maximum integer: '))

urnum = int(input('Enter a number in this range: '))
while urnum < mymin or urnum > mymax:
    print('The number must be between the minimum and the maximum.')
    urnum = int(input('Enter a number between the minimum and the maximum: '))

mycount = 0
randnum = randint(mymin, mymax)
while randnum != urnum:
    mycount = mycount + 1
    randnum = randint(mymin, mymax)

print('It took', mycount, 'random numbers to get', urnum)
# Out:
# Enter a minimum integer: 5
# Enter a maximum integer: 3
# The maximum must be greater than the minimum.
# Enter a maximum integer: 11
# Enter a number in this range: 8
# It took 10 random numbers to get 8

# %% [markdown]
# Write a script that will present the user with choices for functions "1 for round", "2 for floor", "3 for ceil". Error-check by looping to display the choices until the user enters 1, 2, or 3. Then, generate a random real number and print the result of the user's function choice.

# %%
# 4

from random import random
from math import floor, ceil

print("Please choose a function:")
print("1 for round")
print("2 for floor")
print("3 for ceil")

mychoice = int(input('Enter your choice: '))
while mychoice < 1 or mychoice > 3:
    print('The choice must be 1, 2, or 3.')
    mychoice = int(input('Enter your choice: '))

x = random()
if mychoice == 1:
    print(f'The result of round({x:.4f}) is {round(x)}')
elif mychoice == 2:
    print(f'The result of floor({x:.4f}) is {floor(x)}')
else:
    print(f'The result of ceil({x:.4f}) is {ceil(x)}')
# Out:
# Please choose a function:
# 1 for round
# 2 for floor
# 3 for ceil
# Enter your choice: 5
# The choice must be 1, 2, or 3.
# Enter your choice: 1
# The result of round(0.0396) is 0

# %% [markdown]
# Write a script that will prompt the user to enter one of four options: 1, 2, 3, or 'Q' for quit. The script will print different things depending on the user's choice, until the user enters 'Q'. If the user does not enter one of the valid choices, the code will print a different message.

# %%
# 5
urchoice = input('Enter 1, 2, 3, or Q: ')
while urchoice != 'Q':
    if urchoice == '1':
        print('Good job!')
    elif urchoice == '2':
        print('Excellent choice!')
    elif urchoice == '3':
        print('Way to go!')
    else:
        print('Wise guy, eh?')
    urchoice = input('Enter 1, 2, 3, or Q: ')
print('That was fun, huh?')
# Out:
# Enter 1, 2, 3, or Q: 1
# Good job!
# Enter 1, 2, 3, or Q: 1
# Good job!
# Enter 1, 2, 3, or Q: 5
# Wise guy, eh?
# Enter 1, 2, 3, or Q: 3
# Way to go!
# Enter 1, 2, 3, or Q: 2
# Excellent choice!
# Enter 1, 2, 3, or Q: q
# Wise guy, eh?
# Enter 1, 2, 3, or Q: Q
# That was fun, huh?
