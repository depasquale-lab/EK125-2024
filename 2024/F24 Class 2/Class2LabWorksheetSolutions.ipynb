# %% [markdown]
# Class 2: Lab Worksheet
#
# Welcome to lab!  Unlike the excercises in class, you will hand these in, so please test to make sure that all of the code you write works. These exercises are designed to familiarize you with how code works in Python and will help you learn how to generate your own in the future. Please take them seriously and do not use generative AI. Please work in a group of three.
#
# You may be required to write your own code, provide an explanation about what a piece of code is doing, or both.  If you need to add an additional code or text cell, feel free to do that.
#
# Please upload a single copy of this document to gradescope with all partners names associated with it.

# %% [markdown]
# Name:
#
# Partners:

# %% [markdown]
# **Problem 1**: Using Boolean logic and logical operators determine if an integer, *myint*, is divisible by 6.  *myint* can take any value you choose.

# %%
myint = 26
(myint%2 == 0) and (myint%3 == 0)
# Out:
# False

# %% [markdown]
# **Problem 2**: Add the appropriate operators to the following sequence of numbers to obtain a result of 12.5.  Hint:  You'll need one addition, one subtraction, one division, two multiplication and two parenthesis operators.

# %%
(3-1)/(2*2)+ 4*3
# Out:
# 12.5

# %% [markdown]
# **Problem 3**:  What is the difference between x and 'x'?

# %% [markdown]
# x is a variable name, 'x' is the character, or string x

# %% [markdown]
# **Problem 4**:  What is the difference between 5 and '5'?

# %% [markdown]
# 5 is an integer with the value of five, '5' is a character representing the numeral five.

# %% [markdown]
# **Problem 5**:  Determine whether 3 * 10 ** 2 is equal to 3e5 using the equality operator.

# %%
3*10**2 == 3e5
# Out:
# False

# %% [markdown]
# **Problem 6**: What can you do with lists that you cannot do with strings?

# %% [markdown]
# Lists are mutable, while strings are not.  That is, elements of lists can be changed using their indices.  That can't be done with strings.

# %% [markdown]
# **Problem 7**:  Create two string variables, st1 and st2.  Concatenate them to form a third string variable, newstr.  Verify that the length of newstr is the sum of the lengths of st1 and st2.

# %%
st1 = 'string1'
st2 = 'string2'
newstr = st1 + st2
len(st1) + len(st2) == len(newstr)
# Out:
# True

# %% [markdown]
# **Problem 8**:  What happens when you concatenate a string with the empty string?

# %%
st1 + ""
# Out:
# 'string1'

# %% [markdown]
# You get back the original string.  Nothing gets added to it.

# %% [markdown]
# **Problem 9:** What happens when you concatenate a string with spaces to another string?  Do the spaces remain?

# %%
'string with spaces ' + 'do they stay?'
# Out:
# 'string with spaces do they stay?'

# %% [markdown]
# Yes, they do.

# %% [markdown]
# **Problem 10**: Is 'word' equal to "word"?

# %% [markdown]
# Yes!

# %%
'word' == "word"
# Out:
# True
